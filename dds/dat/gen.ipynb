# %%
num = [511, 510, 510, 509, 508, 507, 505, 503, 501, 498, 495, 492, 488, 485, 481, 476,472, 467, 461, 456, 450, 444, 438, 431,424, 417, 410, 402, 395, 386, 378, 370,361, 352, 343, 333, 324, 314, 304, 294,283, 273, 262, 251, 240, 229, 218, 207,195, 183, 172, 160, 148, 136, 124, 111,99 , 87 , 74 , 62 , 50 , 37 , 25 , 12 ,0]

# %%
print(bin(num[0])[2:])
# Out:
# 111111111

# %%
for i in range(len(num)):
	print(bin(num[i])[2:].rjust(9,'0') )
# Out:
# 111111111
# 111111110
# 111111110
# 111111101
# 111111100
# 111111011
# 111111001
# 111110111
# 111110101
# 111110010
# 111101111
# 111101100
# 111101000
# 111100101
# 111100001
# 111011100
# 111011000
# 111010011
# 111001101
# 111001000
# 111000010
# 110111100
# 110110110
# 110101111
# 110101000
# 110100001
# 110011010
# 110010010
# 110001011
# 110000010
# 101111010
# 101110010
# 101101001
# 101100000
# 101010111
# 101001101
# 101000100
# 100111010
# 100110000
# 100100110
# 100011011
# 100010001
# 100000110
# 011111011
# 011110000
# 011100101
# 011011010
# 011001111
# 011000011
# 010110111
# 010101100
# 010100000
# 010010100
# 010001000
# 001111100
# 001101111
# 001100011
# 001010111
# 001001010
# 000111110
# 000110010
# 000100101
# 000011001
# 000001100
# 000000000
